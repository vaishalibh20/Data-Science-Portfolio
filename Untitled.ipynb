# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data=r'C:\Users\bhardwaj\Downloads\default-of-credit-card-clients-dataset\UCI_Credit_Card.csv'

# %%
import seaborn as sns

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv(data)

# %%
df.set_index('ID',inplace=True)

# %%
df.isnull().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
df.dtypes
# Out:
# LIMIT_BAL                     float64
# SEX                             int64
# EDUCATION                       int64
# MARRIAGE                        int64
# AGE                             int64
# PAY_0                           int64
# PAY_2                           int64
# PAY_3                           int64
# PAY_4                           int64
# PAY_5                           int64
# PAY_6                           int64
# BILL_AMT1                     float64
# BILL_AMT2                     float64
# BILL_AMT3                     float64
# BILL_AMT4                     float64
# BILL_AMT5                     float64
# BILL_AMT6                     float64
# PAY_AMT1                      float64
# PAY_AMT2                      float64
# PAY_AMT3                      float64
# PAY_AMT4                      float64
# PAY_AMT5                      float64
# PAY_AMT6                      float64
# default.payment.next.month      int64
# dtype: object

# %%
df.head(10)
# Out:
#     LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 1     20000.0    2          2         1   24      2      2     -1     -1
# 2    120000.0    2          2         2   26     -1      2      0      0
# 3     90000.0    2          2         2   34      0      0      0      0
# 4     50000.0    2          2         1   37      0      0      0      0
# 5     50000.0    1          2         1   57     -1      0     -1      0
# 6     50000.0    1          1         2   37      0      0      0      0
# 7    500000.0    1          1         2   29      0      0      0      0
# 8    100000.0    2          2         2   23      0     -1     -1      0
# 9    140000.0    2          3         1   28      0      0      2      0
# 10    20000.0    1          3         2   35     -2     -2     -2     -2
#
#     PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# ID         ...
# ...

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %% [markdown]
# Amount of billstatement for all given months is correlated with each other.

# %% [markdown]
# The variables most correlated with target variable are the one which show payment status. Other than this Education is correlated with target variable.

# %%
sns.catplot(x='SEX',y='default.payment.next.month', kind="bar",data=df)

# %% [markdown]
# Men default more than Women.

# %%
sns.catplot(x='SEX',y='default.payment.next.month', kind="point",data=df)

# %%
df['default.payment.next.month'].value_counts()
# Out:
# 0    23364
# 1     6636
# Name: default.payment.next.month, dtype: int64

# %%
df['SEX'].value_counts()
# Out:
# 2    18112
# 1    11888
# Name: SEX, dtype: int64

# %%
grouped = df.groupby(['SEX','default.payment.next.month'])
grouped.size()
# Out:
# SEX  default.payment.next.month
# 1    0                              9015
#      1                              2873
# 2    0                             14349
#      1                              3763
# dtype: int64

# %%
sns.catplot(x='SEX',hue='default.payment.next.month', kind="count",data=df)

# %% [markdown]
# In absolute numbere, there are more defaultersin women because of larger share of women in total clients.

# %%
sns.catplot(x='SEX',y='default.payment.next.month', kind="point",data=df)

# %% [markdown]
# It says women are less likely to default as compared to men.
#
# In default.payment.next.month: Default payment (1=yes, 0=no)

# %%
df.PAY_2.value_counts()
# Out:
#  0    15730
# -1     6050
#  2     3927
# -2     3782
#  3      326
#  4       99
#  1       28
#  5       25
#  7       20
#  6       12
#  8        1
# Name: PAY_2, dtype: int64

# %%
cols = ['PAY_0', 'PAY_2','PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']
for i in cols:
    sns.catplot(x=i,y='default.payment.next.month',hue='SEX', kind="point",data=df);

# %%
cols = ['PAY_0', 'PAY_2','PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']
for i in cols:
    sns.catplot(x=i,y='default.payment.next.month', kind="point",data=df);

# %% [markdown]
# The clients whose payment has been delayed in the past are more likely to default this month.

# %%
df['default.payment.next.month'].value_counts()
##UNBALANCED DATASET
# Out:
# 0    23364
# 1     6636
# Name: default.payment.next.month, dtype: int64

# %%
cols = 'BILL_AMT1', 'BILL_AMT2','BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6'
for i in cols:
    g = sns.FacetGrid(df, col="default.payment.next.month")
    g.map(plt.hist, i)

# %%
sns.boxplot(x="default.payment.next.month", y='PAY_AMT1', data=df)

# %%
sns.boxplot(x="default.payment.next.month", y='PAY_AMT2', data=df)

# %%
sns.boxplot(x="default.payment.next.month", y='PAY_AMT3', data=df)

# %%
sns.boxplot(x="default.payment.next.month", y='PAY_AMT4', data=df)

# %%
sns.boxplot(x="default.payment.next.month", y='PAY_AMT5', data=df)

# %%
sns.boxplot(x="default.payment.next.month", y='PAY_AMT6', data=df)

# %% [markdown]
# Previous payment done by non-defaulters are higher than that done by defaulters.

# %%
cols =  'PAY_AMT1','PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6'
for i in cols:
    g = sns.FacetGrid(df, col="default.payment.next.month")
    g.map(plt.hist, i)

# %%
sns.catplot(x='AGE',hue='default.payment.next.month', kind="count",data=df)

# %% [markdown]
# There are more young people in defaulters as compared to the clients who don't default.

# %%
cols =  'PAY_0', 'PAY_2','PAY_3', 'PAY_4', 'PAY_5', 'PAY_6'
for i in cols:
    sns.catplot(x=i,hue='default.payment.next.month', kind="count",data=df)

# %%
sns.catplot(x='EDUCATION',y='default.payment.next.month',hue='SEX', kind="point",data=df);

# %% [markdown]
# It says the clients who are graduated are less likely to default as compared to the one who are educated upto high school.

# %%
sns.catplot(x='EDUCATION',y='default.payment.next.month', kind="point",data=df);

# %%
df.MARRIAGE.value_counts()
# Out:
# 2    15964
# 1    13659
# 3      323
# 0       54
# Name: MARRIAGE, dtype: int64

# %%
sns.catplot(x='MARRIAGE',y='default.payment.next.month',hue='SEX', kind="point",data=df)

# %% [markdown]
# Married male/female more likely to default than unmarried male/female.

# %%
g = sns.FacetGrid(df, col="default.payment.next.month")
g.map(plt.hist, 'LIMIT_BAL')

# %%
sns.catplot(x='default.payment.next.month', kind="count",data=df)

# %%
cols = corrmat.nlargest(11, 'default.payment.next.month')['default.payment.next.month'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# Bill amount 5 and 6 are somewhat correlated with default payment but are also highly correlated with each other.

# %%
df['marriage_sex']=df['MARRIAGE']*df['SEX'] ## no this variable is not useful

# %%
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default.payment.next.month', 'marriage_sex'],
#       dtype='object')

# %%
sns.catplot(x='marriage_sex',y='default.payment.next.month', kind="point",data=df)

# %%
sns.boxplot(x="default.payment.next.month", y='LIMIT_BAL', data=df)

# %% [markdown]
# On average, the amount of given credit to defaulters is less than that for non-defaulters.

# %%
X=df[['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
       'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
       'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
       'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']]

# %%
y=df['default.payment.next.month']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
knn = KNeighborsClassifier(n_neighbors=5, metric='euclidean')

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
y_pred = knn.predict(X_test)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[5360,  472],
#        [1355,  313]], dtype=int64)

# %%
auc = roc_auc_score(y_test, y_pred)

# %%
print('AUC: %.2f' % auc)
# Out:
# AUC: 0.55

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# %%
plt.plot([0, 1], [0, 1], linestyle='--')
plt.plot(fpr, tpr, marker='.')
plt.show()

# %%
from sklearn.metrics import f1_score

# %%
f1_score(y_true = y_test, y_pred = y_pred)
# Out:
# 0.25519771708112515

# %% [markdown]
# SEE notebooks of this set.
# Read about knn in eslii and about scaling ordinal features.
# Grid search cv used in this.
# cut down parameters for the analysis.
# Do we need more parameters? engeenring.
# SEE how can we best visualise the data.
# see how the evaluation is shown best.
# Read best notebook.
